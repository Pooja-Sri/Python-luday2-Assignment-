# %%
print("Hi")
# Out:
# Hi

# %%
name="abc"
mark=98.765
age=20
print ("name",name,"mark",mark,"age",age)
# Out:
# name abc mark 98.765 age 20

# %%
print ("name %s mark %f age %d"% (name,mark,age))
# Out:
# name abc mark 98.765000 age 20

# %%
print("name %5s mark %4.2f age %6d"% (name,mark,age))
# Out:
# name   abc mark 98.77 age     20

# %%
a=10
b=10
a==b
# Out:
# True

# %%
c=a+b
print(c)
# Out:
# 20

# %%
d=a/b
print(d)
# Out:
# 1.0

# %%
a=3
b=4
c=a**b
print(c)
# Out:
# 81

# %%
 a=b=25
print(a,b)
# Out:
# 25 25

# %% [markdown]
#  Arithmetic operators: Exponent- **, Floor division- //, Addition +, subtraction -, division /, modular %

# %% [markdown]
#  Comparison operators, Bitwise operators.
